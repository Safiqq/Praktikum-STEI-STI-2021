# %%
# NIM/Nama  : 16521432/Syafiq Ziyadul Arifin
# Tanggal   : 29 November 2021

import pandas as pd

# Pandas akan membaca file H05.csv yang berada di folder Downloads
df = pd.read_csv("C:/Users/safiq/Downloads/H05.csv")

# %%
# 1. Membuat histogram distribusi nilai matematika mahasiswa
df["nilai_mat"].plot(kind="hist", rwidth=0.8)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
# 2. Membuat diagram batang horizontal berisi banyaknya mahasiswa masing-masing fakultas
df["fakultas"].value_counts().plot(kind = "barh")
# Out:
# <AxesSubplot:>

# %%
# 3. Membuat diagram pie berisi banyaknya mahasiswa masing-masing fakultas
df["fakultas"].value_counts().plot(kind = "pie")
# Out:
# <AxesSubplot:ylabel='fakultas'>

# %%
# 4. Fakultas dengan mahasiswa terbanyak adalah FTI

# Karena jumlah fakultasnya lumayan banyak, maka diagram batang lebih baik dalam menampilkan data jumlah mahasiswa tiap fakultas
# Pada diagram pie, batas antara data jumlah mahasiswa fakultas 1 dengan yang lain cenderung sulit untuk dibaca dengan mata telanjang karena batas-batasnya tidak jelas

# %%
# 5. Membuat scatter plot antara nilai kimia (sumbu-x) dan nilai fisika (sumbu-y)
df.plot(kind="scatter", x="nilai_kim", y="nilai_fis")
# Out:
# <AxesSubplot:xlabel='nilai_kim', ylabel='nilai_fis'>
