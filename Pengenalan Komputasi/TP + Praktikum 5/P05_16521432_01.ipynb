# %%
# NIM/Nama  : 16521432/Syafiq Ziyadul Arifin
# Tanggal   : 1 Desember 2021
# Deskripsi : Diberikan data harga rumah yang disewakan di Airbnb di Singapura
# Judul     : Problem 1 Praktikum 5 Praktikum Pengenalan Komputasi Pengantar 2021-2022

# Kamus
# import pandas as pd: mengimpor library pandas dan meng-assign pandas sebagai pd untuk digunakan
# df: variabel yang membaca data "P05-03.csv"
# .read_csv(): membaca data
# .value_counts(): membaca banyaknya data sesuai dengan nilai tiap data
# .sort_values(): mengurutkan data sesuai dengan kolom tertentu
# ascending: menentukan cara mengurutkan data (menurun atau menaik)
# .loc(): menampilkan data tertentu
# .corr(): korelasi data

# Mulai

# Kita mulai dengan mengimpor modul pandas dan data csv tersebut
import pandas as pd
df = pd.read_csv("C:/Users/safiq/Downloads/P05-03.csv")

# %%
# 1. Banyaknya rumah masing-masing neighbourhood
df["neighbourhood"].value_counts()
# Out:
# Kallang                    1043
# Geylang                     994
# Novena                      537
# Rochor                      536
# Outram                      477
# Bukit Merah                 470
# Downtown Core               428
# Bedok                       373
# River Valley                362
# Queenstown                  266
# Tanglin                     210
# Singapore River             175
# Marine Parade               171
# Jurong West                 153
# Orchard                     136
# Newton                      134
# Bukit Timah                 131
# Jurong East                 118
# Hougang                     109
# Clementi                    102
# Toa Payoh                   101
# Pasir Ris                    71
# Serangoon                    69
# Sengkang                     67
# Woodlands                    67
# Bukit Batok                  65
# Tampines                     64
# Museum                       63
# Choa Chu Kang                63
# ...

# %%
# 2. Jumlah malam penyewaan minimum terbanyak
df["minimum_nights"].value_counts()[:1]
# Out:
# 1    2089
# Name: minimum_nights, dtype: int64

# %%
# 3. 5 data dengan posisi paling selatan (longitude minimum)
df.sort_values("latitude", ascending=1)[:5]
# Out:
#             id                                               name    host_id  \
# 5765  31776450               Singapore's Most Exclusive Penthouse   93747362
# 1215  10638837              Luxury SENTOSA Condo within a Marina!   51190711
# 5714  31527262  Jo's Place Sentosa, a Unique & Romantic Boat Stay  170561338
# 6387  33601064  Staycation on Yacht\nPer night $ (Phone number...  253196803
# 3554  22987047    The Club Residences - 3 BR Suite (Monthly Stay)   84411185
#
#       host_name neighbourhood_group     neighbourhood  latitude  longitude  \
# 5765     Susana      Central Region  Southern Islands   1.24387  103.84246
# 1215      Cheez      Central Region  Southern Islands   1.24391  103.83915
# 5714  Josephine      Central Region  Southern Islands   1.24526  103.83999
# 6387      Carol      Central Region  Southern Islands   1.24627  103.84063
# 3554     Darren      Central Region  Southern Islands   1.24847  103.82389
#
# ...

# %%
# 4. Rumah yang ada di neighbourhood group West Region
df.loc[df["neighbourhood_group"] == "West Region"]
# Out:
#             id                                               name    host_id  \
# 24      553229              Comfortable Condo Room - Boon Lay MRT    1030128
# 58     1060046  S$950/mth spacious room for short/long term lease    5748910
# 89     1646909                     Cozy room, convenient location    8739736
# 105    1813277                    Student Guardianship & Homestay    9497281
# 122    2033483                ★2+1condo next to MRT, mall & more★    9497281
# ...        ...                                                ...        ...
# 7752  37798739                      near Clementi MRT female only  157856583
# 7782  37887437             西部文理有保安的公寓楼下就是地铁站+巴士总站+商场｡南洋理工大学NUS附近｡  183511167
# 7856  38007847             Spacious 3 bedroom at Perfect location  238891646
# 7867  38028286                         Nearby NUS big common room  288546201
# 7900  38102097                                            环境优雅的公寓  286260560
#
# ...

# %%
# 5. Koefisien korelasi antara banyak review di aplikasi dengan banyaknya hari ketersediaan rumah dalam satu tahun
df["number_of_reviews"].corr(df["availability_365"])
# Karena koefisien korelasinya mendekati 0, maka banyak review di aplikasi dengan banyaknya hari ketersediaan rumah dalam satu tahun
# tidak berkorelasi antara satu dengan yang lain
# Out:
# -0.0666580643449999
